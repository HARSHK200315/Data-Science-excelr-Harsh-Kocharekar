# %% [markdown]
# ## Exercise 1: Prime Number Checker

# %%
# Function to check if a number is prime
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True

# Example
num = 29
print(f"{num} is prime:", is_prime(num))
# Out:
# 29 is prime: True

# %% [markdown]
# ## Exercise 2: Product of Random Numbers

# %%
import random

# Generate two random numbers
a = random.randint(1, 10)
b = random.randint(1, 10)

print("Random numbers:", a, b)

user_answer = a * b 
print("User entered:", user_answer)

if user_answer == a * b:
    print("Correct!")
else:
    print("Incorrect.")
# Out:
# Random numbers: 8 8
# User entered: 64
# Correct!

# %% [markdown]
# ## Exercise 3: Squares of Even Numbers (Choice: EVEN numbers)

# %%
# Printing squares of EVEN numbers between 100 and 200

squares = {n: n**2 for n in range(100, 201) if n % 2 == 0}
squares
# Out:
# {100: 10000,
#  102: 10404,
#  104: 10816,
#  106: 11236,
#  108: 11664,
#  110: 12100,
#  112: 12544,
#  114: 12996,
#  116: 13456,
#  118: 13924,
#  120: 14400,
#  122: 14884,
#  124: 15376,
#  126: 15876,
#  128: 16384,
#  130: 16900,
#  132: 17424,
#  134: 17956,
#  136: 18496,
#  138: 19044,
#  140: 19600,
#  142: 20164,
#  144: 20736,
#  146: 21316,
#  148: 21904,
#  150: 22500,
#  152: 23104,
#  154: 23716,
#  156: 24336,
#  158: 24964,
#  160: 25600,
#  162: 26244,
#  164: 26896,
#  166: 27556,
#  168: 28224,
#  170: 28900,
#  172: 29584,
#  174: 30276,
#  176: 30976,
#  178: 31684,
#  180: 32400,
#  182: 33124,
#  184: 33856,
#  186: 34596,
#  188: 35344,
#  190: 36100,
#  192: 36864,
#  194: 37636,
#  196: 38416,
#  198: 39204,
#  200: 40000}

# %% [markdown]
# ## Exercise 4: Word Counter

# %%
from collections import Counter

input_text = "This is a sample text. This text will be used to demonstrate the word counter."

# Convert to lower and split
words = input_text.split()

count = Counter(words)

for word, freq in count.items():
    print(f"'{word}': {freq}")
# Out:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1
# 'text': 1
# 'will': 1
# 'be': 1
# 'used': 1
# 'to': 1
# 'demonstrate': 1
# 'the': 1
# 'word': 1
# 'counter.': 1

# %% [markdown]
# ## Exercise 5: Palindrome Checker

# %%
import re

def is_palindrome(text):
    cleaned = re.sub(r'[^A-Za-z0-9]', '', text).lower()
    return cleaned == cleaned[::-1]

# Example
print(is_palindrome("racecar"))
print(is_palindrome("A man a plan a canal Panama"))
# Out:
# True
# True
